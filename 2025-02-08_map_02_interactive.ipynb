# %% [markdown]
# # Display Interactive Map
#
# - If the interactive map doesn't display, try this link: https://nbviewer.org/github/tiangenglu/map/blob/main/2025-02-08_map_02_interactive.ipynb
# - Author: Tiangeng Lu
# - Time: 2025-02-08

# %%
import os
import time as tm
import getpass
print(f'Last run on {tm.strftime("%Y-%m-%d, %A, %H:%M:%S")}')
import pandas as pd
import geopandas as gpd
from matplotlib import pyplot as plt
import folium
import fiona
print(fiona.__version__)
print(gpd.__version__)
# Out:
# Last run on 2025-02-08, Saturday, 17:43:54
# 1.9.6
# 0.14.2

# %%
input_folder = getpass.getpass("Enter the input directory and press ENTER: ")

# %%
dbf_cd_42 = gpd.read_file(input_folder + '/tl_2024_42_cd119.dbf')
print(f'The type of the input `.dbf` file is: {type(dbf_cd_42)}')
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona/ogrext.pyx:136, in fiona.ogrext.gdal_open_vector()
#
# File fiona/_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: /tl_2024_42_cd119.dbf: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dbf_cd_42 = gpd.read_file(input_folder + '/tl_2024_42_cd119.dbf')
#       2 print(f'The type of the input `.dbf` file is: {type(dbf_cd_42)}')
#
# File ~/opt/anaconda3/envs/py312/lib/python3.12/site-packages/geopandas/io/file.py:297, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     294     else:
#     295         path_or_bytes = filename
# --> 297     return _read_file_fiona(
# ...

# %%
dbf_cd_42.explore(tooltip = ['GEOID','CD119FP','NAMELSAD'])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
